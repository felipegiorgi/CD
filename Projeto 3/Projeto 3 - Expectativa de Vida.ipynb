# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
dadosEx = pd.read_excel('indicator life_expectancy_at_birth.xlsx',sep = '')

dadosIDH = pd.read_excel('Indicator_HDI.xlsx',sep = '') 

dadosPob = pd.read_excel('Indicator_Poverty headcount ratio at $1.25 a day (PPP) (% of population).xlsx', sep=' ')

# %%
dadosEx.head()
# Out:
#          Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...    2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...    52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...    76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...    75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# ...

# %%
dadosIDH.head()
# Out:
#                      HDI   1980   1990   2000   2005   2006   2007   2008  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  0.198  0.246  0.230  0.340  0.354  0.363  0.370
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania    NaN  0.656  0.691  0.721  0.724  0.729  0.733
# 4                Algeria  0.454  0.551  0.624  0.667  0.673  0.680  0.686
#
#     2009   2011
# 0    NaN    NaN
# 1  0.387  0.398
# 2    NaN    NaN
# 3  0.734  0.739
# 4  0.691  0.698

# %%
dadosPob.head()
# Out:
#   Poverty headcount ratio at $1.25 a day (PPP) (% of population)  1974  1975  \
# 0                                        Afghanistan               NaN   NaN
# 1                                            Albania               NaN   NaN
# 2                                            Algeria               NaN   NaN
# 3                                             Angola               NaN   NaN
# 4                                          Argentina               NaN   NaN
#
#    1976  1977  1978  1979  1980  1981  1982  ...   2004  2005  2006  2007  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.53  0.44   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   6.29  4.62  3.76  3.01
#
#    2008   2009  2010  2011  2012  2013
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f34c0690341f> in <module>()
# ----> 1 dadosEx = dadosEx[~np.isnan(dadosEx)]
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
